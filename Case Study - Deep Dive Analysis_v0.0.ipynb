# %% [markdown]
# ## Case - Deep Dive Analysis
#
# Background:
# There are multiple instances where the Value Sales have decreased for different manufacturers in the last month compared to the month before that and it is important for the business to understand the exact area or level from where the drop is coming from
#
# Objective:
# To create a generic Python function which can do a deep dive analysis and give out exact focus area which are behind the cause of drop of Value Sales for a particular Manufacturer
#
# Steps to follow:
# 1. Check if there is a drop in the Value Sales in the target month compared to last month
# 2. If Step 1 shows an increase then print "There is no drop in the sales for a <particular manufacturer> in the <specified time period>"
# 3. If Step 1 shows a drop, then proceed by picking different deep dive options: Product level, Geographical level
# 4. To do a deep dive on levels - zone,region,brand,subbrand
# 5. calculate the growth rate of sales in the target month and contribution to overall value sales
# 6. Take a product of the above two metrics to get a decisive metric which can then be sorted accordingly to get the actual focus area
# 7. Expected final input to the function:
#
#     func(Manufacturer = "X", target_period = "May2019", reference_period = "Apr2019")
#
# 8. Expected final output of the function:
#
#
#     Manufacturer	level	focus_area	growth_rate	contribution	product
#     X	            Zone		               -20%	         50%	  -0.10
#     X	            Zone		               -30%	         10%	  -0.03
#     X	            Zone
#     X	            Zone
#     X	            Subbrand
#     X	            Subbrand
#     X	            Region		             -15%	         30%	  -0.05
#     X	            Region
#     X	            Brand		              -25%	          5%	  -0.01
#     X
#
#
# Additional Information:
# 1. There is a Geographical Level Hierarchy - Zone, Region
# 2. There is a Product Level Hierarchy- Manufacturer, Brand, Subbrand, Item
# 3. Pack Type and Pack Size are present under Item level
# 4. Formula for growth_rate = ( Value Sales (focus_area) (target_period) - Value Sales (focus_area) (reference_period) ) * 100 / Value Sales (focus_area) (reference_period)
# 5. Formula for contribution = Value Sales (focus_area) (target_period) * 100 / Value Sales (X) (target_period)
# 6. Formula for product = growth_rate * contribution
# 7. Focus Area can be any individual value of Geographical Level Hierarchy and Product Level Hierarchy. For example, North Zone, Urban, Brand 1, Subbrand 1
#
#
# ## Data Dictionary
#         Label Name	   Label Description
#             Zone	     Geographical Zone
#             Region	     Geographical Region
#       Manufacturer	     Name of the company
#             Brand	     Name of the brand
#           Subbrand	     Name of the subbrand
#             Item	     Name of the item
#            PackSize	     Pack size of items
#            Packtype	     Type of pack of items
#             month	     month of sale
#   Value Offtake(000 Rs)    Value Sales in Rs. Thousands

# %% [markdown]
# #### Import the libraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load the file from stage location

# %%
location = 'D:/Xzane/Priyesh/Courses - Training materials/Companies/LT/case study/Case Study - Deep Dive Analysis.xlsx'

# %%
df_file = pd.read_excel(location,sheet_name = 'input_data')

# %%
df_file.head(50)
# Out:
#     Zone Region     Manufacturer      Brand                       Subbrand  \
# 0   East  Rural  GLAXOSMITHKLINE   HORLICKS                  HORLICKS LITE
# 1   East  Rural  GLAXOSMITHKLINE   HORLICKS                WOMENS HORLICKS
# 2   East  Rural  GLAXOSMITHKLINE      BOOST                   BOOST SPORTS
# 3   East  Rural  GLAXOSMITHKLINE   HORLICKS  HORLICKS HEALTH AND NUTRITION
# 4   East  Rural  GLAXOSMITHKLINE      BOOST        BOOST HEALTH AND ENERGY
# 5   East  Rural  GLAXOSMITHKLINE   HORLICKS                WOMENS HORLICKS
# 6   East  Rural  GLAXOSMITHKLINE   HORLICKS  HORLICKS HEALTH AND NUTRITION
# 7   East  Rural  GLAXOSMITHKLINE   HORLICKS  HORLICKS HEALTH AND NUTRITION
# 8   East  Rural  GLAXOSMITHKLINE   HORLICKS                WOMENS HORLICKS
# 9   East  Rural         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 10  East  Rural         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 11  East  Rural         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 12  East  Rural         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 13  East  Rural         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 14  East  Rural         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 15  East  Rural         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 16  East  Rural      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
# 17  East  Rural      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
# 18  East  Rural      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
# 19  East  Rural      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
# 20  East  Rural      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
# 21  East  Rural      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
# 22  East  Rural             AMUL       AMUL                  AMUL PRO WHEY
# 23  East  Rural             AMUL       AMUL                  AMUL PRO WHEY
# 24  East  Rural             AMUL       AMUL                  AMUL PRO WHEY
# 25  East  Rural             AMUL       AMUL                  AMUL PRO WHEY
# 26  East  Rural             AMUL       AMUL                  AMUL PRO WHEY
# 27  East  Rural           NESTLE       MILO                 MILO ACTIVE GO
# 28  East  Rural           NESTLE       MILO                 MILO ACTIVE GO
# 29  East  Rural           NESTLE       MILO                 MILO ACTIVE GO
# 30  East  Rural           NESTLE       MILO                 MILO ACTIVE GO
# 31  East  Rural           NESTLE       MILO                 MILO ACTIVE GO
# 32  East  Urban  GLAXOSMITHKLINE   HORLICKS                WOMENS HORLICKS
# 33  East  Urban  GLAXOSMITHKLINE   HORLICKS  HORLICKS HEALTH AND NUTRITION
# 34  East  Urban  GLAXOSMITHKLINE   HORLICKS                  HORLICKS LITE
# 35  East  Urban  GLAXOSMITHKLINE      BOOST                   BOOST SPORTS
# 36  East  Urban  GLAXOSMITHKLINE      BOOST        BOOST HEALTH AND ENERGY
# 37  East  Urban  GLAXOSMITHKLINE   HORLICKS                WOMENS HORLICKS
# 38  East  Urban  GLAXOSMITHKLINE   HORLICKS  HORLICKS HEALTH AND NUTRITION
# 39  East  Urban  GLAXOSMITHKLINE   HORLICKS  HORLICKS HEALTH AND NUTRITION
# 40  East  Urban  GLAXOSMITHKLINE   HORLICKS                WOMENS HORLICKS
# 41  East  Urban         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 42  East  Urban         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 43  East  Urban         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 44  East  Urban         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 45  East  Urban         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 46  East  Urban         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 47  East  Urban         MONDELEZ  BOURNVITA            BOURNVITA PROHEALTH
# 48  East  Urban      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
# 49  East  Urban      KRAFT FOODS    COMPLAN       COMPLAN ROYALE CHOCOLATE
#
#                                                  Item  PackSize     Packtype  \
# 0                   HORLICKS LITE 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 1                 WOMENS HORLICKS 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 2                    BOOST SPORTS 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 3   HORLICKS HEALTH AND NUTRITION 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 4       BOOST HEALTH AND ENERGYÂ  500 GMS REFILL PACK   500 GMS  REFILL PACK
# 5                 WOMENS HORLICKS 750 GMS REFILL PACK   750 GMS  REFILL PACK
# 6   HORLICKS HEALTH AND NUTRITION 750 GMS REFILL PACK   750 GMS  REFILL PACK
# 7   HORLICKS HEALTH AND NUTRITION 1000 GMS REFILL ...  1000 GMS  REFILL PACK
# 8                WOMENS HORLICKS 1000 GMS REFILL PACK  1000 GMS  REFILL PACK
# 9             BOURNVITA PROHEALTH 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 10                                    MONDELEZ_item_1   500 GMS  REFILL PACK
# 11                                    MONDELEZ_item_2   500 GMS  REFILL PACK
# 12                                    MONDELEZ_item_3   500 GMS  REFILL PACK
# 13                                    MONDELEZ_item_4   500 GMS  REFILL PACK
# 14                                    MONDELEZ_item_5   500 GMS  REFILL PACK
# 15                                    MONDELEZ_item_6   500 GMS  REFILL PACK
# 16      COMPLAN ROYALE CHOCOLATE 1000 GMS REFILL PACK  1000 GMS  REFILL PACK
# 17                                 KRAFT FOODS_item_1  1000 GMS  REFILL PACK
# 18                                 KRAFT FOODS_item_2  1000 GMS  REFILL PACK
# 19                                 KRAFT FOODS_item_3  1000 GMS  REFILL PACK
# 20                                 KRAFT FOODS_item_4  1000 GMS  REFILL PACK
# 21                                 KRAFT FOODS_item_5  1000 GMS  REFILL PACK
# 22                          AMUL PRO WHEY 250 GMS JAR   250 GMS          JAR
# 23                                        AMUL_item_1   250 GMS          JAR
# 24                                        AMUL_item_2   250 GMS          JAR
# 25                                        AMUL_item_3   250 GMS          JAR
# 26                                        AMUL_item_4   250 GMS          JAR
# 27                 MILO ACTIVE GO 400 GMS REFILL PACK   400 GMS  REFILL PACK
# 28                                      NESTLE_item_1   400 GMS  REFILL PACK
# 29                                      NESTLE_item_2   400 GMS  REFILL PACK
# 30                                      NESTLE_item_3   400 GMS  REFILL PACK
# 31                                      NESTLE_item_4   400 GMS  REFILL PACK
# 32                WOMENS HORLICKS 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 33  HORLICKS HEALTH AND NUTRITION 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 34                  HORLICKS LITE 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 35                   BOOST SPORTS 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 36      BOOST HEALTH AND ENERGYÂ  500 GMS REFILL PACK   500 GMS  REFILL PACK
# 37                WOMENS HORLICKS 750 GMS REFILL PACK   750 GMS  REFILL PACK
# 38  HORLICKS HEALTH AND NUTRITION 750 GMS REFILL PACK   750 GMS  REFILL PACK
# 39  HORLICKS HEALTH AND NUTRITION 1000 GMS REFILL ...  1000 GMS  REFILL PACK
# 40               WOMENS HORLICKS 1000 GMS REFILL PACK  1000 GMS  REFILL PACK
# 41            BOURNVITA PROHEALTH 500 GMS REFILL PACK   500 GMS  REFILL PACK
# 42                                    MONDELEZ_item_1   500 GMS  REFILL PACK
# 43                                    MONDELEZ_item_2   500 GMS  REFILL PACK
# 44                                    MONDELEZ_item_3   500 GMS  REFILL PACK
# 45                                    MONDELEZ_item_4   500 GMS  REFILL PACK
# 46                                    MONDELEZ_item_5   500 GMS  REFILL PACK
# 47                                    MONDELEZ_item_6   500 GMS  REFILL PACK
# 48      COMPLAN ROYALE CHOCOLATE 1000 GMS REFILL PACK  1000 GMS  REFILL PACK
# 49                                 KRAFT FOODS_item_1  1000 GMS  REFILL PACK
#
#         month  Value Offtake(000 Rs)
# 0  2019-01-01               4883.050
# 1  2019-01-01               4460.013
# 2  2019-01-01               3230.254
# 3  2019-01-01               4548.961
# 4  2019-01-01               2993.130
# 5  2019-01-01               2312.412
# 6  2019-01-01               1603.273
# 7  2019-01-01                995.398
# 8  2019-01-01                632.588
# 9  2019-01-01                800.874
# 10 2019-01-01                624.030
# 11 2019-01-01                335.631
# 12 2019-01-01                186.473
# 13 2019-01-01                179.568
# 14 2019-01-01                185.524
# 15 2019-01-01                155.644
# 16 2019-01-01                113.097
# 17 2019-01-01                 72.274
# 18 2019-01-01                 31.380
# 19 2019-01-01                  0.000
# 20 2019-01-01                  0.000
# 21 2019-01-01                  0.000
# 22 2019-01-01                 14.449
# 23 2019-01-01                  0.000
# 24 2019-01-01                  0.000
# 25 2019-01-01                  0.000
# 26 2019-01-01                  0.000
# 27 2019-01-01                812.522
# 28 2019-01-01                235.573
# 29 2019-01-01                217.184
# 30 2019-01-01                111.443
# 31 2019-01-01                 46.848
# 32 2019-01-01               8989.834
# 33 2019-01-01               8345.387
# 34 2019-01-01               6636.123
# 35 2019-01-01               2768.851
# 36 2019-01-01               4298.576
# 37 2019-01-01               2693.191
# 38 2019-01-01               3745.921
# 39 2019-01-01               3003.238
# 40 2019-01-01               2757.569
# 41 2019-01-01               2894.020
# 42 2019-01-01               1605.790
# 43 2019-01-01               1073.109
# 44 2019-01-01               1181.893
# 45 2019-01-01               1363.578
# 46 2019-01-01                921.916
# 47 2019-01-01                650.025
# 48 2019-01-01                488.030
# 49 2019-01-01                461.192

# %%
df_file.isnull().sum()
# Out:
# Zone                     0
# Region                   0
# Manufacturer             0
# Brand                    0
# Subbrand                 0
# Item                     0
# PackSize                 0
# Packtype                 0
# month                    0
# Value Offtake(000 Rs)    0
# dtype: int64

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zone                   1280 non-null   object
#  1   Region                 1280 non-null   object
#  2   Manufacturer           1280 non-null   object
#  3   Brand                  1280 non-null   object
#  4   Subbrand               1280 non-null   object
#  5   Item                   1280 non-null   object
#  6   PackSize               1280 non-null   object
#  7   Packtype               1280 non-null   object
#  8   month                  1280 non-null   datetime64[ns]
#  9   Value Offtake(000 Rs)  1280 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 100.1+ KB

# %%
df_file.describe()
# Out:
#        Value Offtake(000 Rs)
# count            1280.000000
# mean              957.548663
# std              1822.845836
# min                 0.000000
# 25%                37.425000
# 50%               233.151500
# 75%               929.909250
# max             17548.553000

# %% [markdown]
# ###### Except Value OffTake(000 Rs) others are categorial features. Also highly deviated observed from std value

# %%
df = df_file.copy()

# %%
#df_file_test['Geo_lvl']= df_file_test['Zone'].str.cat(df_file_test['Region'], sep=",")
#df_file_test['Prod_lvl']= df_file_test['Brand']+','+df_file_test['Subbrand']+','+df_file_test['Item']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zone                   1280 non-null   object
#  1   Region                 1280 non-null   object
#  2   Manufacturer           1280 non-null   object
#  3   Brand                  1280 non-null   object
#  4   Subbrand               1280 non-null   object
#  5   Item                   1280 non-null   object
#  6   PackSize               1280 non-null   object
#  7   Packtype               1280 non-null   object
#  8   month                  1280 non-null   datetime64[ns]
#  9   Value Offtake(000 Rs)  1280 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 100.1+ KB

# %% [markdown]
# """
# import sqlit`e3
# db_path = "C:/Users/priye/PythonProjects/database/LntCaseStudy.db"
# con = sqlite3.connect(db_path)
# cur = con.cursor()
# df_file_test.to_sql('LNT', con, if_exists='replace', index=False)
# con.commit()
# con.close()
# """

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zone                   1280 non-null   object
#  1   Region                 1280 non-null   object
#  2   Manufacturer           1280 non-null   object
#  3   Brand                  1280 non-null   object
#  4   Subbrand               1280 non-null   object
#  5   Item                   1280 non-null   object
#  6   PackSize               1280 non-null   object
#  7   Packtype               1280 non-null   object
#  8   month                  1280 non-null   datetime64[ns]
#  9   Value Offtake(000 Rs)  1280 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 100.1+ KB

# %%
cols=['PackSize','Packtype']
#col=['month_new']
df.drop(cols,axis=1,inplace=True)

# %%
df.rename(columns={"Value Offtake(000 Rs)":"Value Sales"},inplace=True)
df.head()
# Out:
#    Zone Region     Manufacturer     Brand                       Subbrand  \
# 0  East  Rural  GLAXOSMITHKLINE  HORLICKS                  HORLICKS LITE
# 1  East  Rural  GLAXOSMITHKLINE  HORLICKS                WOMENS HORLICKS
# 2  East  Rural  GLAXOSMITHKLINE     BOOST                   BOOST SPORTS
# 3  East  Rural  GLAXOSMITHKLINE  HORLICKS  HORLICKS HEALTH AND NUTRITION
# 4  East  Rural  GLAXOSMITHKLINE     BOOST        BOOST HEALTH AND ENERGY
#
#                                                 Item      month  Value Sales
# 0                  HORLICKS LITE 500 GMS REFILL PACK 2019-01-01     4883.050
# 1                WOMENS HORLICKS 500 GMS REFILL PACK 2019-01-01     4460.013
# 2                   BOOST SPORTS 500 GMS REFILL PACK 2019-01-01     3230.254
# 3  HORLICKS HEALTH AND NUTRITION 500 GMS REFILL PACK 2019-01-01     4548.961
# 4      BOOST HEALTH AND ENERGYÂ  500 GMS REFILL PACK 2019-01-01     2993.130

# %%
level_df = pd.DataFrame([('Zone', 'East'),
                       ('Zone', 'North'),
                       ('Zone', 'South'),
                       ('Zone', 'West'),
                       ('Region', 'Rural'),
                       ('Region', 'Urban'),
                       ('Brand', 'AMUL'),
                       ('Brand', 'BOOST'),
                       ('Brand', 'BOURNVITA'),
                       ('Brand', 'COMPLAN'),
                       ('Brand', 'HORLICKS'),
                       ('Brand', 'MILO'),
                       ('Subbrand', 'AMUL PRO WHEY'),
                       ('Subbrand', 'BOOST HEALTH AND ENERGY'),
                       ('Subbrand', 'BOOST SPORTS'),
                       ('Subbrand', 'BOURNVITA PROHEALTH'),
                       ('Subbrand', 'COMPLAN ROYALE CHOCOLATE'),
                       ('Subbrand', 'HORLICKS HEALTH AND NUTRITION'),
                       ('Subbrand', 'HORLICKS LITE'),
                       ('Subbrand', 'MILO ACTIVE GO'),
                       ('Subbrand', 'WOMENS HORLICKS')],
                      columns = ['Level', 'focus_area'])
level_df.set_index('focus_area')
# Out:
#                                   Level
# focus_area
# East                               Zone
# North                              Zone
# South                              Zone
# West                               Zone
# Rural                            Region
# Urban                            Region
# AMUL                              Brand
# BOOST                             Brand
# BOURNVITA                         Brand
# COMPLAN                           Brand
# HORLICKS                          Brand
# MILO                              Brand
# AMUL PRO WHEY                  Subbrand
# BOOST HEALTH AND ENERGY        Subbrand
# BOOST SPORTS                   Subbrand
# BOURNVITA PROHEALTH            Subbrand
# COMPLAN ROYALE CHOCOLATE       Subbrand
# HORLICKS HEALTH AND NUTRITION  Subbrand
# HORLICKS LITE                  Subbrand
# MILO ACTIVE GO                 Subbrand
# WOMENS HORLICKS                Subbrand

# %%
# For Overall
df_grp_man = df.groupby(['Manufacturer','month'], sort=True, as_index=False)['Value Sales'].sum()
df_grp_man['diff_frm_prev_month'] = df_grp_man.groupby('Manufacturer')['Value Sales'].diff()

# %%
df_grp_man.head(10)
# Out:
#       Manufacturer      month  Value Sales  diff_frm_prev_month
# 0             AMUL 2019-01-01     1525.574                  NaN
# 1             AMUL 2019-02-01     1807.457              281.883
# 2             AMUL 2019-03-01     1755.112              -52.345
# 3             AMUL 2019-04-01     1955.994              200.882
# 4             AMUL 2019-05-01     1410.972             -545.022
# 5  GLAXOSMITHKLINE 2019-01-01   201960.379                  NaN
# 6  GLAXOSMITHKLINE 2019-02-01   197328.072            -4632.307
# 7  GLAXOSMITHKLINE 2019-03-01   176568.680           -20759.392
# 8  GLAXOSMITHKLINE 2019-04-01   158163.671           -18405.009
# 9  GLAXOSMITHKLINE 2019-05-01   176433.256            18269.585

# %%
# For zone 
df_grp_Z = df.groupby(['Manufacturer','month','Zone'], sort=True, as_index=False)['Value Sales'].sum()
df_grp_Z['diff_frm_prev_month'] = df_grp_Z.groupby(['Manufacturer','Zone'])['Value Sales'].diff()

# %%
df_grp_Z.head()
# Out:
#   Manufacturer      month   Zone  Value Sales  diff_frm_prev_month
# 0         AMUL 2019-01-01   East       80.591                  NaN
# 1         AMUL 2019-01-01  North      236.700                  NaN
# 2         AMUL 2019-01-01  South      849.921                  NaN
# 3         AMUL 2019-01-01   West      358.362                  NaN
# 4         AMUL 2019-02-01   East      139.413               58.822

# %%
# For Zone_Region 
df_grp_ZR = df.groupby(['Manufacturer','month','Zone','Region'], sort=True, as_index=False)['Value Sales'].sum()
df_grp_ZR['diff_frm_prev_month'] = df_grp_ZR.groupby(['Manufacturer','Zone','Region'])['Value Sales'].diff()

# %%
df_grp_ZR.head()
# Out:
#   Manufacturer      month   Zone Region  Value Sales  diff_frm_prev_month
# 0         AMUL 2019-01-01   East  Rural       14.449                  NaN
# 1         AMUL 2019-01-01   East  Urban       66.142                  NaN
# 2         AMUL 2019-01-01  North  Rural        0.000                  NaN
# 3         AMUL 2019-01-01  North  Urban      236.700                  NaN
# 4         AMUL 2019-01-01  South  Rural       91.383                  NaN

# %%
# For Zone_Region_Brand 
df_grp_ZRB = df.groupby(['Manufacturer','month','Zone','Region','Brand'], sort=True, as_index=False)['Value Sales'].sum()
df_grp_ZRB['diff_frm_prev_month'] = df_grp_ZRB.groupby(['Manufacturer','Zone','Region','Brand'])['Value Sales'].diff()

# %%
df_grp_ZRB.head()
# Out:
#   Manufacturer      month   Zone Region Brand  Value Sales  \
# 0         AMUL 2019-01-01   East  Rural  AMUL       14.449
# 1         AMUL 2019-01-01   East  Urban  AMUL       66.142
# 2         AMUL 2019-01-01  North  Rural  AMUL        0.000
# 3         AMUL 2019-01-01  North  Urban  AMUL      236.700
# 4         AMUL 2019-01-01  South  Rural  AMUL       91.383
#
#    diff_frm_prev_month
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# For Zone_Region_Brand_Subbrand 
df_grp_ZRBS = df.groupby(['Manufacturer','month','Zone','Region','Brand','Subbrand'], sort=True, as_index=False)['Value Sales'].sum()
df_grp_ZRBS['diff_frm_prev_month'] = df_grp_ZRBS.groupby(['Manufacturer','Zone','Region','Brand','Subbrand'])['Value Sales'].diff()

# %%
def manufacturer(manu,date1,date2):
    if date2 <= date1:
        print("Invalid Date selection. Try again!!")
    else:
        neg_vals_Z = df_grp_Z[(df_grp_Z['diff_frm_prev_month']<0)&(df_grp_Z['Manufacturer']==manu) & (df_grp_Z['month']==date2)]
        neg_vals_Z['prev_Value Sales'] = neg_vals_Z['Value Sales'] - neg_vals_Z['diff_frm_prev_month']
        neg_vals_Z['growth rate'] = neg_vals_Z['diff_frm_prev_month']/neg_vals_Z['prev_Value Sales'] #).astype(str) + '%'
        neg_vals_Z['contribution'] = neg_vals_Z['Value Sales']/ df_grp_man['Value Sales'][(df_grp_man['month']==date2)&(df_grp_man['Manufacturer']==manu)].values[0] #).astype(str) + '%'
        neg_vals_Z['product']=neg_vals_Z['growth rate'] * neg_vals_Z['contribution']
        net_df_grp_Z = neg_vals_Z[['Manufacturer','Zone','growth rate','contribution','product']]
        net_df_grp_Z=net_df_grp_Z.groupby(['Manufacturer','Zone'],sort=True, as_index=False).sum()
        net_df_grp_Z.rename(columns={"Zone":"focus_area"},inplace=True)
        #print(net_df_grp_Z)
        
        neg_vals_R = df_grp_ZR[(df_grp_ZR['diff_frm_prev_month']<0)&(df_grp_ZR['Manufacturer']==manu) & (df_grp_ZR['month']==date2)]
        neg_vals_R['prev_Value Sales'] = neg_vals_R['Value Sales'] - neg_vals_R['diff_frm_prev_month']
        neg_vals_R['growth rate'] = neg_vals_R['diff_frm_prev_month']/neg_vals_R['prev_Value Sales'] #).astype(str) + '%'
        neg_vals_R['contribution'] = neg_vals_R['Value Sales']/ df_grp_man['Value Sales'][(df_grp_man['month']==date2)&(df_grp_man['Manufacturer']==manu)].values[0] #).astype(str) + '%'
        neg_vals_R['product']=neg_vals_R['growth rate'] * neg_vals_R['contribution']
        net_df_grp_ZR = neg_vals_R[['Manufacturer','Region','growth rate','contribution','product']]
        net_df_grp_ZR=net_df_grp_ZR.groupby(['Manufacturer','Region'],sort=True, as_index=False).sum()
        net_df_grp_ZR.rename(columns={"Region":"focus_area"},inplace=True)
        #print(net_df_grp_ZR)
        
        neg_vals_B = df_grp_ZRB[(df_grp_ZRB['diff_frm_prev_month']<0)&(df_grp_ZRB['Manufacturer']==manu) & (df_grp_ZRB['month']==date2)]
        neg_vals_B['prev_Value Sales'] = neg_vals_B['Value Sales'] - neg_vals_B['diff_frm_prev_month']
        neg_vals_B['growth rate'] = neg_vals_B['diff_frm_prev_month']/neg_vals_B['prev_Value Sales'] #).astype(str) + '%'
        neg_vals_B['contribution'] = neg_vals_B['Value Sales']/ df_grp_man['Value Sales'][(df_grp_man['month']==date2)&(df_grp_man['Manufacturer']==manu)].values[0] #).astype(str) + '%'
        neg_vals_B['product']=neg_vals_B['growth rate'] * neg_vals_B['contribution']
        net_df_grp_ZRB = neg_vals_B[['Manufacturer','Brand','growth rate','contribution','product']]
        net_df_grp_ZRB=net_df_grp_ZRB.groupby(['Manufacturer','Brand'],sort=True, as_index=False).sum()
        net_df_grp_ZRB.rename(columns={"Brand":"focus_area"},inplace=True)
        #print(net_df_grp_ZRB)
        
        
        neg_vals = df_grp_ZRBS[(df_grp_ZRBS['diff_frm_prev_month']<0)&(df_grp_ZRBS['Manufacturer']==manu) & (df_grp_ZRBS['month']==date2)]
        neg_vals['prev_Value Sales'] = neg_vals['Value Sales'] - neg_vals['diff_frm_prev_month']
        neg_vals['growth rate'] = neg_vals['diff_frm_prev_month']/neg_vals['prev_Value Sales'] #).astype(str) + '%'
        neg_vals['contribution'] = neg_vals['Value Sales']/ df_grp_man['Value Sales'][(df_grp_man['month']==date2)&(df_grp_man['Manufacturer']==manu)].values[0] #).astype(str) + '%'
        neg_vals['product']=neg_vals['growth rate'] * neg_vals['contribution']
        net_df_grp_ZRBS = neg_vals[['Manufacturer','Subbrand','growth rate','contribution','product']]
        net_df_grp_ZRBS=net_df_grp_ZRBS.groupby(['Manufacturer','Subbrand'],sort=True, as_index=False).sum()
        net_df_grp_ZRBS.rename(columns={"Subbrand":"focus_area"},inplace=True)
        #print(f"\n\n{net_df_grp_ZRBS}")
        
        dfs = [net_df_grp_Z,net_df_grp_ZR,net_df_grp_ZRB,net_df_grp_ZRBS]
        df_con= pd.concat(dfs,axis=0,ignore_index=True, sort=False)
        df_con.set_index('focus_area',inplace=True)
        df_con =  pd.merge(df_con, level_df, how='left', on=['focus_area'])
        df_con.reset_index(drop=True,inplace= True)
        final_df = df_con[['Manufacturer','Level','focus_area','growth rate','contribution','product']]
        return(final_df)
            

manufacturer('KRAFT FOODS','2019-03-01','2019-04-01')
# Out:
#   Manufacturer     Level                focus_area  growth rate  contribution  \
# 0  KRAFT FOODS      Zone                      East    -0.259213      0.181949
# 1  KRAFT FOODS      Zone                     South    -0.008678      0.125672
# 2  KRAFT FOODS      Zone                      West    -0.073576      0.350887
# 3  KRAFT FOODS    Region                     Rural    -1.103542      0.006589
# 4  KRAFT FOODS    Region                     Urban    -0.383361      0.893365
# 5  KRAFT FOODS     Brand                   COMPLAN    -1.486903      0.899954
# 6  KRAFT FOODS  Subbrand  COMPLAN ROYALE CHOCOLATE    -1.486903      0.899954
#
#     product
# 0 -0.047164
# 1 -0.001091
# 2 -0.025817
# 3 -0.004229
# 4 -0.089176
# 5 -0.093405
# 6 -0.093405

# %%
# 4 to 1 mapping
# last step to map 

import numpy as np
level_map={}
cols=['Zone','Region','Brand','Subbrand']
for i in range(len(cols)):
    x = [x for x in df.columns if x in cols[i]]
    #print(x)
    col_val =np.unique(df[x].values) 
    #print(col_val)
    for i in range(len(col_val)):
        level_map[col_val[i]]=x
   
    
        
    #print('\n')

#print(pd.DataFrame(level_map))
#print(level_map)

# %%
df_list= [df_grp_Z,df_grp_ZR,df_grp_ZRB,df_grp_ZRBS]

# %%
for i in range(len(df_list)):
    tempdf = df_list[i]
    tempdf['level'] = 0 #= df[x].map(level_map)
    df_new=tempdf
#print(df_new)

# %%
df_grp_ZRB['Level']=df['Region'].map(level_map)

# %%
df_grp_ZRB.head()
# Out:
#   Manufacturer      month   Zone Region Brand  Value Sales  \
# 0         AMUL 2019-01-01   East  Rural  AMUL       14.449
# 1         AMUL 2019-01-01   East  Urban  AMUL       66.142
# 2         AMUL 2019-01-01  North  Rural  AMUL        0.000
# 3         AMUL 2019-01-01  North  Urban  AMUL      236.700
# 4         AMUL 2019-01-01  South  Rural  AMUL       91.383
#
#    diff_frm_prev_month  level     Level
# 0                  NaN      0  [Region]
# 1                  NaN      0  [Region]
# 2                  NaN      0  [Region]
# 3                  NaN      0  [Region]
# 4                  NaN      0  [Region]

# %%
cols=['Zone','Region','Brand','Subbrand']
for i in range(len(cols)):
    x = [x for x in df.columns if x in cols[i]]
    #print(x)
    #df_grp_ZRB['Level']=df['Region'].map(level_map)
    for i in range(len(df_list)):
        tempdf=0
        tempdf = df_list[i]
        tempdf['level'] = df[x]
        print(tempdf)
# Out:
#    Manufacturer      month   Zone  Value Sales  diff_frm_prev_month  level
# 0          AMUL 2019-01-01   East       80.591                  NaN   East
# 1          AMUL 2019-01-01  North      236.700                  NaN   East
# 2          AMUL 2019-01-01  South      849.921                  NaN   East
# 3          AMUL 2019-01-01   West      358.362                  NaN   East
# 4          AMUL 2019-02-01   East      139.413               58.822   East
# ..          ...        ...    ...          ...                  ...    ...
# 95       NESTLE 2019-04-01   West     2658.452             -248.780  North
# 96       NESTLE 2019-05-01   East     3197.894              656.629  North
# 97       NESTLE 2019-05-01  North     3314.420              -59.308  North
# 98       NESTLE 2019-05-01  South     1485.547               65.020  North
# 99       NESTLE 2019-05-01   West     2738.004               79.552  North
#
# [100 rows x 6 columns]
#     Manufacturer      month   Zone Region  Value Sales  diff_frm_prev_month  \
# 0           AMUL 2019-01-01   East  Rural       14.449                  NaN
# 1           AMUL 2019-01-01   East  Urban       66.142                  NaN
# 2           AMUL 2019-01-01  North  Rural        0.000                  NaN
# 3           AMUL 2019-01-01  North  Urban      236.700                  NaN
# 4           AMUL 2019-01-01  South  Rural       91.383                  NaN
# ..           ...        ...    ...    ...          ...                  ...
# 195       NESTLE 2019-05-01  North  Urban     2520.914              138.810
# 196       NESTLE 2019-05-01  South  Rural      266.968               32.380
# 197       NESTLE 2019-05-01  South  Urban     1218.579               32.640
# 198       NESTLE 2019-05-01   West  Rural      503.869             -166.019
# 199       NESTLE 2019-05-01   West  Urban     2234.135              245.571
#
#     level
# 0    East
# 1    East
# 2    East
# 3    East
# 4    East
# ..    ...
# 195  West
# 196  West
# 197  West
# 198  West
# 199  West
#
# [200 rows x 7 columns]
#     Manufacturer      month   Zone Region Brand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL       91.383
# ..           ...        ...    ...    ...   ...          ...
# 235       NESTLE 2019-05-01  North  Urban  MILO     2520.914
# 236       NESTLE 2019-05-01  South  Rural  MILO      266.968
# 237       NESTLE 2019-05-01  South  Urban  MILO     1218.579
# 238       NESTLE 2019-05-01   West  Rural  MILO      503.869
# 239       NESTLE 2019-05-01   West  Urban  MILO     2234.135
#
#      diff_frm_prev_month level     Level
# 0                    NaN  East  [Region]
# 1                    NaN  East  [Region]
# 2                    NaN  East  [Region]
# 3                    NaN  East  [Region]
# 4                    NaN  East  [Region]
# ..                   ...   ...       ...
# 235              138.810  West  [Region]
# 236               32.380  West  [Region]
# 237               32.640  West  [Region]
# 238             -166.019  West  [Region]
# 239              245.571  West  [Region]
#
# [240 rows x 9 columns]
#     Manufacturer      month   Zone Region Brand        Subbrand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL   AMUL PRO WHEY       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL   AMUL PRO WHEY       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL   AMUL PRO WHEY        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL   AMUL PRO WHEY      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL   AMUL PRO WHEY       91.383
# ..           ...        ...    ...    ...   ...             ...          ...
# 355       NESTLE 2019-05-01  North  Urban  MILO  MILO ACTIVE GO     2520.914
# 356       NESTLE 2019-05-01  South  Rural  MILO  MILO ACTIVE GO      266.968
# 357       NESTLE 2019-05-01  South  Urban  MILO  MILO ACTIVE GO     1218.579
# 358       NESTLE 2019-05-01   West  Rural  MILO  MILO ACTIVE GO      503.869
# 359       NESTLE 2019-05-01   West  Urban  MILO  MILO ACTIVE GO     2234.135
#
#      diff_frm_prev_month  level
# 0                    NaN   East
# 1                    NaN   East
# 2                    NaN   East
# 3                    NaN   East
# 4                    NaN   East
# ..                   ...    ...
# 355              138.810  North
# 356               32.380  North
# 357               32.640  North
# 358             -166.019  North
# 359              245.571  North
#
# [360 rows x 9 columns]
#    Manufacturer      month   Zone  Value Sales  diff_frm_prev_month  level
# 0          AMUL 2019-01-01   East       80.591                  NaN  Rural
# 1          AMUL 2019-01-01  North      236.700                  NaN  Rural
# 2          AMUL 2019-01-01  South      849.921                  NaN  Rural
# 3          AMUL 2019-01-01   West      358.362                  NaN  Rural
# 4          AMUL 2019-02-01   East      139.413               58.822  Rural
# ..          ...        ...    ...          ...                  ...    ...
# 95       NESTLE 2019-04-01   West     2658.452             -248.780  Rural
# 96       NESTLE 2019-05-01   East     3197.894              656.629  Urban
# 97       NESTLE 2019-05-01  North     3314.420              -59.308  Urban
# 98       NESTLE 2019-05-01  South     1485.547               65.020  Urban
# 99       NESTLE 2019-05-01   West     2738.004               79.552  Urban
#
# [100 rows x 6 columns]
#     Manufacturer      month   Zone Region  Value Sales  diff_frm_prev_month  \
# 0           AMUL 2019-01-01   East  Rural       14.449                  NaN
# 1           AMUL 2019-01-01   East  Urban       66.142                  NaN
# 2           AMUL 2019-01-01  North  Rural        0.000                  NaN
# 3           AMUL 2019-01-01  North  Urban      236.700                  NaN
# 4           AMUL 2019-01-01  South  Rural       91.383                  NaN
# ..           ...        ...    ...    ...          ...                  ...
# 195       NESTLE 2019-05-01  North  Urban     2520.914              138.810
# 196       NESTLE 2019-05-01  South  Rural      266.968               32.380
# 197       NESTLE 2019-05-01  South  Urban     1218.579               32.640
# 198       NESTLE 2019-05-01   West  Rural      503.869             -166.019
# 199       NESTLE 2019-05-01   West  Urban     2234.135              245.571
#
#      level
# 0    Rural
# 1    Rural
# 2    Rural
# 3    Rural
# 4    Rural
# ..     ...
# 195  Rural
# 196  Rural
# 197  Rural
# 198  Rural
# 199  Rural
#
# [200 rows x 7 columns]
#     Manufacturer      month   Zone Region Brand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL       91.383
# ..           ...        ...    ...    ...   ...          ...
# 235       NESTLE 2019-05-01  North  Urban  MILO     2520.914
# 236       NESTLE 2019-05-01  South  Rural  MILO      266.968
# 237       NESTLE 2019-05-01  South  Urban  MILO     1218.579
# 238       NESTLE 2019-05-01   West  Rural  MILO      503.869
# 239       NESTLE 2019-05-01   West  Urban  MILO     2234.135
#
#      diff_frm_prev_month  level     Level
# 0                    NaN  Rural  [Region]
# 1                    NaN  Rural  [Region]
# 2                    NaN  Rural  [Region]
# 3                    NaN  Rural  [Region]
# 4                    NaN  Rural  [Region]
# ..                   ...    ...       ...
# 235              138.810  Urban  [Region]
# 236               32.380  Urban  [Region]
# 237               32.640  Urban  [Region]
# 238             -166.019  Urban  [Region]
# 239              245.571  Urban  [Region]
#
# [240 rows x 9 columns]
#     Manufacturer      month   Zone Region Brand        Subbrand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL   AMUL PRO WHEY       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL   AMUL PRO WHEY       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL   AMUL PRO WHEY        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL   AMUL PRO WHEY      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL   AMUL PRO WHEY       91.383
# ..           ...        ...    ...    ...   ...             ...          ...
# 355       NESTLE 2019-05-01  North  Urban  MILO  MILO ACTIVE GO     2520.914
# 356       NESTLE 2019-05-01  South  Rural  MILO  MILO ACTIVE GO      266.968
# 357       NESTLE 2019-05-01  South  Urban  MILO  MILO ACTIVE GO     1218.579
# 358       NESTLE 2019-05-01   West  Rural  MILO  MILO ACTIVE GO      503.869
# 359       NESTLE 2019-05-01   West  Urban  MILO  MILO ACTIVE GO     2234.135
#
#      diff_frm_prev_month  level
# 0                    NaN  Rural
# 1                    NaN  Rural
# 2                    NaN  Rural
# 3                    NaN  Rural
# 4                    NaN  Rural
# ..                   ...    ...
# 355              138.810  Urban
# 356               32.380  Urban
# 357               32.640  Urban
# 358             -166.019  Urban
# 359              245.571  Urban
#
# [360 rows x 9 columns]
#    Manufacturer      month   Zone  Value Sales  diff_frm_prev_month     level
# 0          AMUL 2019-01-01   East       80.591                  NaN  HORLICKS
# 1          AMUL 2019-01-01  North      236.700                  NaN  HORLICKS
# 2          AMUL 2019-01-01  South      849.921                  NaN     BOOST
# 3          AMUL 2019-01-01   West      358.362                  NaN  HORLICKS
# 4          AMUL 2019-02-01   East      139.413               58.822     BOOST
# ..          ...        ...    ...          ...                  ...       ...
# 95       NESTLE 2019-04-01   West     2658.452             -248.780      MILO
# 96       NESTLE 2019-05-01   East     3197.894              656.629  HORLICKS
# 97       NESTLE 2019-05-01  North     3314.420              -59.308  HORLICKS
# 98       NESTLE 2019-05-01  South     1485.547               65.020  HORLICKS
# 99       NESTLE 2019-05-01   West     2738.004               79.552  HORLICKS
#
# [100 rows x 6 columns]
#     Manufacturer      month   Zone Region  Value Sales  diff_frm_prev_month  \
# 0           AMUL 2019-01-01   East  Rural       14.449                  NaN
# 1           AMUL 2019-01-01   East  Urban       66.142                  NaN
# 2           AMUL 2019-01-01  North  Rural        0.000                  NaN
# 3           AMUL 2019-01-01  North  Urban      236.700                  NaN
# 4           AMUL 2019-01-01  South  Rural       91.383                  NaN
# ..           ...        ...    ...    ...          ...                  ...
# 195       NESTLE 2019-05-01  North  Urban     2520.914              138.810
# 196       NESTLE 2019-05-01  South  Rural      266.968               32.380
# 197       NESTLE 2019-05-01  South  Urban     1218.579               32.640
# 198       NESTLE 2019-05-01   West  Rural      503.869             -166.019
# 199       NESTLE 2019-05-01   West  Urban     2234.135              245.571
#
#         level
# 0    HORLICKS
# 1    HORLICKS
# 2       BOOST
# 3    HORLICKS
# 4       BOOST
# ..        ...
# 195  HORLICKS
# 196  HORLICKS
# 197  HORLICKS
# 198  HORLICKS
# 199     BOOST
#
# [200 rows x 7 columns]
#     Manufacturer      month   Zone Region Brand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL       91.383
# ..           ...        ...    ...    ...   ...          ...
# 235       NESTLE 2019-05-01  North  Urban  MILO     2520.914
# 236       NESTLE 2019-05-01  South  Rural  MILO      266.968
# 237       NESTLE 2019-05-01  South  Urban  MILO     1218.579
# 238       NESTLE 2019-05-01   West  Rural  MILO      503.869
# 239       NESTLE 2019-05-01   West  Urban  MILO     2234.135
#
#      diff_frm_prev_month      level     Level
# 0                    NaN   HORLICKS  [Region]
# 1                    NaN   HORLICKS  [Region]
# 2                    NaN      BOOST  [Region]
# 3                    NaN   HORLICKS  [Region]
# 4                    NaN      BOOST  [Region]
# ..                   ...        ...       ...
# 235              138.810  BOURNVITA  [Region]
# 236               32.380  BOURNVITA  [Region]
# 237               32.640  BOURNVITA  [Region]
# 238             -166.019  BOURNVITA  [Region]
# 239              245.571  BOURNVITA  [Region]
# [240 rows x 9 columns]
#     Manufacturer      month   Zone Region Brand        Subbrand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL   AMUL PRO WHEY       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL   AMUL PRO WHEY       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL   AMUL PRO WHEY        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL   AMUL PRO WHEY      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL   AMUL PRO WHEY       91.383
# ..           ...        ...    ...    ...   ...             ...          ...
# 355       NESTLE 2019-05-01  North  Urban  MILO  MILO ACTIVE GO     2520.914
# 356       NESTLE 2019-05-01  South  Rural  MILO  MILO ACTIVE GO      266.968
# 357       NESTLE 2019-05-01  South  Urban  MILO  MILO ACTIVE GO     1218.579
# 358       NESTLE 2019-05-01   West  Rural  MILO  MILO ACTIVE GO      503.869
# 359       NESTLE 2019-05-01   West  Urban  MILO  MILO ACTIVE GO     2234.135
#
#      diff_frm_prev_month     level
# 0                    NaN  HORLICKS
# 1                    NaN  HORLICKS
# 2                    NaN     BOOST
# 3                    NaN  HORLICKS
# 4                    NaN     BOOST
# ..                   ...       ...
# 355              138.810  HORLICKS
# 356               32.380  HORLICKS
# 357               32.640     BOOST
# 358             -166.019     BOOST
# 359              245.571  HORLICKS
#
# [360 rows x 9 columns]
#    Manufacturer      month   Zone  Value Sales  diff_frm_prev_month  \
# 0          AMUL 2019-01-01   East       80.591                  NaN
# 1          AMUL 2019-01-01  North      236.700                  NaN
# 2          AMUL 2019-01-01  South      849.921                  NaN
# 3          AMUL 2019-01-01   West      358.362                  NaN
# 4          AMUL 2019-02-01   East      139.413               58.822
# ..          ...        ...    ...          ...                  ...
# 95       NESTLE 2019-04-01   West     2658.452             -248.780
# 96       NESTLE 2019-05-01   East     3197.894              656.629
# 97       NESTLE 2019-05-01  North     3314.420              -59.308
# 98       NESTLE 2019-05-01  South     1485.547               65.020
# 99       NESTLE 2019-05-01   West     2738.004               79.552
#
#                             level
# 0                   HORLICKS LITE
# 1                 WOMENS HORLICKS
# 2                    BOOST SPORTS
# 3   HORLICKS HEALTH AND NUTRITION
# 4         BOOST HEALTH AND ENERGY
# ..                            ...
# 95                 MILO ACTIVE GO
# 96  HORLICKS HEALTH AND NUTRITION
# 97                WOMENS HORLICKS
# 98  HORLICKS HEALTH AND NUTRITION
# 99                WOMENS HORLICKS
#
# [100 rows x 6 columns]
#     Manufacturer      month   Zone Region  Value Sales  diff_frm_prev_month  \
# 0           AMUL 2019-01-01   East  Rural       14.449                  NaN
# 1           AMUL 2019-01-01   East  Urban       66.142                  NaN
# 2           AMUL 2019-01-01  North  Rural        0.000                  NaN
# 3           AMUL 2019-01-01  North  Urban      236.700                  NaN
# 4           AMUL 2019-01-01  South  Rural       91.383                  NaN
# ..           ...        ...    ...    ...          ...                  ...
# 195       NESTLE 2019-05-01  North  Urban     2520.914              138.810
# 196       NESTLE 2019-05-01  South  Rural      266.968               32.380
# 197       NESTLE 2019-05-01  South  Urban     1218.579               32.640
# 198       NESTLE 2019-05-01   West  Rural      503.869             -166.019
# 199       NESTLE 2019-05-01   West  Urban     2234.135              245.571
#
#                              level
# 0                    HORLICKS LITE
# 1                  WOMENS HORLICKS
# 2                     BOOST SPORTS
# 3    HORLICKS HEALTH AND NUTRITION
# 4          BOOST HEALTH AND ENERGY
# ..                             ...
# 195                WOMENS HORLICKS
# 196                  HORLICKS LITE
# 197                WOMENS HORLICKS
# 198  HORLICKS HEALTH AND NUTRITION
# 199        BOOST HEALTH AND ENERGY
#
# [200 rows x 7 columns]
#     Manufacturer      month   Zone Region Brand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL       91.383
# ..           ...        ...    ...    ...   ...          ...
# 235       NESTLE 2019-05-01  North  Urban  MILO     2520.914
# 236       NESTLE 2019-05-01  South  Rural  MILO      266.968
# 237       NESTLE 2019-05-01  South  Urban  MILO     1218.579
# 238       NESTLE 2019-05-01   West  Rural  MILO      503.869
# 239       NESTLE 2019-05-01   West  Urban  MILO     2234.135
#
#      diff_frm_prev_month                          level     Level
# 0                    NaN                  HORLICKS LITE  [Region]
# 1                    NaN                WOMENS HORLICKS  [Region]
# 2                    NaN                   BOOST SPORTS  [Region]
# 3                    NaN  HORLICKS HEALTH AND NUTRITION  [Region]
# 4                    NaN        BOOST HEALTH AND ENERGY  [Region]
# ..                   ...                            ...       ...
# 235              138.810            BOURNVITA PROHEALTH  [Region]
# 236               32.380            BOURNVITA PROHEALTH  [Region]
# 237               32.640            BOURNVITA PROHEALTH  [Region]
# 238             -166.019            BOURNVITA PROHEALTH  [Region]
# 239              245.571            BOURNVITA PROHEALTH  [Region]
#
# [240 rows x 9 columns]
#     Manufacturer      month   Zone Region Brand        Subbrand  Value Sales  \
# 0           AMUL 2019-01-01   East  Rural  AMUL   AMUL PRO WHEY       14.449
# 1           AMUL 2019-01-01   East  Urban  AMUL   AMUL PRO WHEY       66.142
# 2           AMUL 2019-01-01  North  Rural  AMUL   AMUL PRO WHEY        0.000
# 3           AMUL 2019-01-01  North  Urban  AMUL   AMUL PRO WHEY      236.700
# 4           AMUL 2019-01-01  South  Rural  AMUL   AMUL PRO WHEY       91.383
# ..           ...        ...    ...    ...   ...             ...          ...
# 355       NESTLE 2019-05-01  North  Urban  MILO  MILO ACTIVE GO     2520.914
# 356       NESTLE 2019-05-01  South  Rural  MILO  MILO ACTIVE GO      266.968
# 357       NESTLE 2019-05-01  South  Urban  MILO  MILO ACTIVE GO     1218.579
# 358       NESTLE 2019-05-01   West  Rural  MILO  MILO ACTIVE GO      503.869
# 359       NESTLE 2019-05-01   West  Urban  MILO  MILO ACTIVE GO     2234.135
#
#      diff_frm_prev_month                          level
# 0                    NaN                  HORLICKS LITE
# 1                    NaN                WOMENS HORLICKS
# 2                    NaN                   BOOST SPORTS
# 3                    NaN  HORLICKS HEALTH AND NUTRITION
# 4                    NaN        BOOST HEALTH AND ENERGY
# ..                   ...                            ...
# 355              138.810                WOMENS HORLICKS
# 356               32.380                  HORLICKS LITE
# 357               32.640                   BOOST SPORTS
# 358             -166.019        BOOST HEALTH AND ENERGY
# 359              245.571  HORLICKS HEALTH AND NUTRITION
#
# [360 rows x 9 columns]

# %%
from pandas_profiling import ProfileReport as pr
profile = pr(df=df,title = "Profiling report of case study",html={'style':{'full_width':True}})
profile.to_widgets()
# Out:
# Summarize dataset: 100%|██████████| 22/22 [00:10<00:00,  2.19it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:07<00:00,  7.05s/it]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…
