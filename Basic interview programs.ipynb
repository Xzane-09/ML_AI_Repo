# %%
# Basic Programs

# Program for factorial of a number:
"""
Method 1:

n = 5
fact = 1

while n > 1:
    print(f'{n}*')
    fact = n * fact
    n = n - 1
print(fact)
#------------------------------------------
Method 2:
def fac(n):
    return 1 if (n == 1 or n == 0) else n * fac(n-1)

print(fac(5))
"""

"""
# Compound interest:
p = 1200
r = 5.4
t = 2

A = p*(1 + (r/100))**t
print(f'Compound Interest: {A} $')
"""

# Armstrong:
"""
# Variable initialize:
x = int(input("Enter the number to check armstrong:"))
n = x
temp = x
count = 0

# print("\nGetting the count")
while x != 0:
    count = count + 1
    x = x // 10
# print(count)

# print("\ndigits calculate")
sm = 0
while temp != 0:
    p = temp % 10
    sm = sm + pow(p, count)
    q = temp//10  # int((temp - p)/10)
    temp = q

# print(f"p:{p}, q:{q}, temp:{temp}, sum:{sm}")

# Print armstrong or not
if sm != n:
    print("Not an Armstrong")
else:
    print("Armstrong")
"""

# To print even length of words from bag of words and remove empty spaces as well:
"""
# set punctuation

punc = ''',.!:""''&()'''
lts = []
strng = "How are you, dear. Hope you are well. Will call you today"

for word in strng:
    if word in punc:
        strng = strng.replace(word, " ")

strng = strng.split(" ")
print(strng)
for word in strng:
    if len(word) % 2 == 0 and word not in punc:
        lts.append(word)

print(lts)
"""

# To remove empty spaces from a list:
"""
x = ['gfg', '   ', ' ', 'is', '            ', 'best']
res_str = [ele for ele in x if ele.split()]
print(res_str)
"""

# To remove extra empty spaces from string:
# method 1: Regex
"""
import regex as re
test_str = "GfG  is   good           website"
res = re.sub(' +', ' ', test_str)
print(res)
"""
# method 2: using join() and split()
"""
test_str = "GfG  is   good           website"
res = " ".join(test_str.split())
print(res)
"""


# To remove whitespaces in a word:
"""
# Method 1:
res = " ".join(input_string.split())

# Method 2:
res = string.replace(" ", ' ')

# Method 3: Regex
pattern = re.compile(r'\s+')
re.sub(pattern, ' ', string)
"""


# To remove and print every third number from the list:
"""
# list starts with 
# 0 index 
pos = 3 - 1
index = 0
len_list = (len( int_list ))

# breaks out once the 
# list becomes empty 
while len_list > 0:
    index = (pos + index) % len_list

    # removes and prints the required 
    # element 
    print(int_list.pop(index))
    len_list -= 1
"""

# To print frequency of each letter in a given string
"""
import pandas as pd
exam_str = "I want to leave my native"
list_str = list(exam_str)
# Remove blank spaces from the list
list_str = [ele for ele in list_str if ele.split()]
series_list_str = pd.Series(list_str)
VC_series_list_str = series_list_str.value_counts()
print(VC_series_list_str)
"""

# To print frequency of each word in a given string
"""
import pandas as pd

exam_str = "I want to leave my native"
# Treatment of blanks
list_str = exam_str.split(" ")
# list_str = list(exam_str)
series_list_str = pd.Series(list_str)
print(series_list_str.value_counts())
"""

# To Remove space from column names of a Dataframe:
"""
import pandas as pd

# create data frame
Data = {'Employee Name': ['Mukul', 'Rohan', 'Mayank',
                          'Shubham', 'Aakash'],

        'Location': ['Saharanpur', 'Meerut', 'Agra',
                     'Saharanpur', 'Meerut'],

        'Sales Code': ['muk123', 'roh232', 'may989',
                       'shu564', 'aka343']}
df = pd.DataFrame(Data)

print(df)
new_df = df.copy()
new_df.columns = df.columns.str.replace(' ', '')

print("\n\n", new_df)
"""

# To remove numeric digits from a given string
"""
import pandas as pd
given_str = 'Priyesh1009Chakraborty0909'
digits = '''1234567890'''
print(f"Given String: {given_str}")
series_str = pd.Series(given_str)
strng = "".join([i for i in given_str if not i.isdigit()])
print(strng)
"""

# Regex problems:

"""
\   Used to drop the special meaning of character
    following it (discussed below)
[]  Represent a character class
^   Matches the beginning
$   Matches the end
.   Matches any character except newline
?   Matches zero or one occurrence.
|   Means OR (Matches with any of the characters
    separated by it.
*   Any number of occurrences (including 0 occurrences)
+   One or more occurrences
{}  Indicate number of occurrences of a preceding RE 
    to match.
()  Enclose a group of REs
"""

"""
    \d   Matches any decimal digit, this is equivalent to the set class [0-9].
    \D   Matches any non-digit character.
    \s   Matches any whitespace character.
    \S   Matches any non-whitespace character
    \w   Matches any alphanumeric character, this is equivalent to the class [a-zA-Z0-9_].
    \W   Matches any non-alphanumeric character. 
"""

# Here 'p' means pattern

# Function compile() -- it creates a
"""
import re
p = re.compile('[a-e,A-P]')
print(p.findall("Priyesh Chakraborty"))
"""

# To check above mentioned options like : '\s' -- white spaces
"""
import re
p = re.compile('\w+')
print(p.findall('priyesh 09 - 1990 , sept'))
"""

# To check the number of occurrences of a character
"""
import re
p = re.compile('ab*')
print(p.findall('aabbaabbbababbabbb'))
"""
"""
import re

# Splitting will occurs only once, at '12', returned list will have length 2
p = re.compile(r'\d+th')
print(re.split(p, 'On 12th Jan 2016, at 11:02 AM', 1))
"""
"""
# Func sub() and subn() :
# with subn function, it sends the number of time a replacement happened
import re
input_string = "G89 - TP - blk - h - s"
print(f"Given String: {input_string}")
# now replace " - " with "-"
pattern = " - "
replace_pattern = "-"
given_string = input_string
print("Output with sub: ", re.sub(pattern=pattern, repl=replace_pattern, string=given_string))
print("Output with subn: ", re.subn(pattern=pattern, repl=replace_pattern, string=given_string))
"""

# Func escape() : Return string with all non-alphanumerics backslashed
"""
import re

# escape() returns a string with BackSlash '\', before every Non-Alphanumeric Character
# In 1st case only ' ', is not alphanumeric
# In 2nd case, ' ', caret '^', '-', '[]', '\' are not alphanumeric
print(re.escape("This is Awseome even 1 AM"))
print(re.escape("I Asked what is this [a-9], he said \t ^WoW"))
"""
# To remove the ith (index) character from the input string:
"""
import re
input_string = "GeeksForGeeks"

# using join and lambda
ind_num = int(input(f"Enter the index number to omit in the given {range(len(input_string)-1)}: "))
print("Using join and lambda: ", "".join([input_string[i] for i in range(len(input_string)) if i != ind_num]))

# using slice-dice and concatenation
print("Using slice-dice and concatenation: ", input_string[0:ind_num] + input_string[ind_num+1:])

# Using sub:
# use '\' before " -- to remove the effect of '"'
print(f"Using sub, to remove \"{input_string[ind_num]}\":", re.sub(pattern=input_string[ind_num], repl='',
                                                                   string=input_string, flags=re.IGNORECASE, count=1))

# Using Replace function:
print("Using Replace functon", input_string.replace(input_string[ind_num], '', 1))
"""

# To check if a Substring is Present in a Given String
"""
import re
input_str = 'Priyesh Chakraborty'
sub_str = 'Priy'
print("The below output is by using re.match function: ")
if re.match(sub_str, input_str):
    print("It's a match")
else:
    print("Not a match")

print("\n\nThe below output is by using re.search function: ")
if re.search(pattern=sub_str, string=input_str):
    print("It's a match")
else:
    print("Not a match")
"""

# TO print the frequency of words chosen/given from input string(input_str)
"""
from collections import Counter
import pandas as pd
input_str = "Geeks for geeks are good to read and good to practice for learners"
print(input_str)

count_list = ['best', 'geeksforgeeks', 'computer', 'better', 'And', 'and', 'to', 'good']

# computing frequency using Counter()
# res = Counter(input_str.split())
# print(res)

str_list = input_str.split()
str_list_series = pd.Series(str_list)
x = str_list_series.value_counts().reset_index(inplace=False, name='Counts').values
print(x)
print("\n"*2, "\nBelow is the output")
count = 0
for i in x:
    if i.any() in count_list:
        print(i)
    # else:
    #    print("No Words are found")
    #    break
"""
# To Check if given words appear together(In same sequence) in a list of sentence
"""
sentence = ['python coder', 'geeksforgeeks', 'coder in geeksforgeeks']
words = ['coder', 'geeksforgeeks']
res_words = []
for sentence_words in sentence:
    k = [w for w in words if w in sentence_words]
    if len(k) == len(words):
        res_words.append(k)
print(res_words)
"""

# Remove duplicate words from Strings in List
"""
import re
p = re.compile('\W+')
strng = 'This is an example of removing duplicate words in this given string. Take this example and' \
        ' try removing duplicate words.'
print(f"Given String: \n{strng}")

no_dups = re.split(pattern=p, string=strng)
no_dups = [ele for ele in no_dups if ele.split()]
no_dups = sorted(set(no_dups))
print(no_dups)
"""

# Dictionary operations:
"""
import collections
# Usage of "ord"
# print(range(ord('g')))

od = collections.OrderedDict()

print("Regular Dict")
d = {chr(k): k for k in range(ord('a'), ord('g'))}
for k, v in d.items():
    print(k, v)

print("\nOrdered Dict")
[od.setdefault(chr(k), k) for k in range(ord('a'), ord('g'))]
for k, v in od.items():
    print(k, v)


# inserting the values manually:

od['A'] = 5


print("\n"*2)
print(od.keys())
print(od.items())

print("\n"*2)
for k, v in od.items():
    print(k, v)

od['a'] = 45
print("\n"*2)
for k, v in od.items():
    print(k, v)
"""

# Pretty dictionary:
"""
test_dict = {'gfg': {'rate': 5, 'remark': 'good', 'rank': '3'}, 'cs': {'rate': 'c'}}

for k, v in test_dict.items():
    print(f"{k}---")
    for k1, v1 in v.items():
        print(f"{k1}: {v1}")
    print("\n")
"""

# to find all given number divisible by 13
"""
my_list = [12, 65, 54, 39, 102, 339, 221, 50, 70]
print(my_list)
# using list comprehension
print("Using List Comprehension")
d = [num for num in my_list if num % 13 == 0]
print(d)

# Now, using lambda and filter
print("\nUsing lambda and filter")
print(list(filter(lambda x: x % 13 == 0, my_list)))
"""

# To find all palindromes from a list of strings:
"""
my_list = ["geeks", "geeg", "keek", "practice", "aa"]
print("Given String:\n", my_list)
print("\nTest run for slicing:")
print(my_list[3][::-1], "\n")

words = [word for word in my_list if word == word[::-1]]
print("Pallindromes in a given list using slicing:\n", words)

# using lambda and filter function:
print("\nPallindromes in a given list using filter and lambda:\n", list(filter(lambda x: (x == "".join(reversed(x))),
                                                                               my_list)))
"""

# Created a Dataframe
"""
import pandas as pd
import re
import numpy as np
from sklearn.impute import SimpleImputer

df = pd.DataFrame({
    'Name': ['Akash', 'Ashish', 'Ayush',
             'Diksha', 'Radhika', 'Ronit', 'Abhinav', 'Anil', 'Osman', 'Uday'],

    'Comments': ['Hey! Akash how r u',
                 'Why are you asking this to me?',
                 'See you in some time',
                 'Today, what we are going to do.',
                 'Will meet soon',
                 'No plans for today why?',
                 'Wedding plans, what are you saying?',
                 'Not this Year',
                 'Hope to see you again',
                 'Greeting!!'],
    'DOB': ['06/11/2000', '12/21/1998', '15/12/1998',
            '06/11/2000', '12/21/1998', '05/10/1998',
            '13/12/2010', '06/11/2000', '12/21/1998', '15/12/1998'],
    'Age': [20, 21, 22, 20, np.nan, 21, np.nan, np.nan, 21, np.nan]
    },

    columns=['Name', 'Comments', 'DOB', 'Age']
)
# print(df)
 """

# To store csv data to a sqlite db
"""
import csv
import sqlite3
import pandas as pd
file_path = "E:/Xzane/Priyesh/Courses - Training materials/Simplilearn/Machine Learning/" \
            "class notes,ppt,ipynb,datasets,etc/Demo Datasets/Lesson 3/SalaryGender.csv"
file = pd.read_csv(file_path)
data_cols = file.columns  # use list(dataframe) to get column names as list
# print(data_cols)
# print(file.info())

db_path = "C:/Users/priye/PythonProjects/database/RetailFirm.db"
con = sqlite3.connect(db_path)
cur = con.cursor()
cur.execute(f"DROP TABLE IF EXISTS train;")
cur.execute(f" CREATE TABLE train (Salary, Gender, Age, PhD);")
with open(file_path, 'r') as fin:
    dr = csv.DictReader(fin)  # comma is default delimiter
    to_db = [(i['Salary'], i['Gender'], i['Age'], i['PhD']) for i in dr]

cur.executemany("INSERT INTO train (Salary, Gender, Age, PhD) VALUES (?, ?, ?, ?);", to_db)
con.commit()
con.close()

"""

# TO store a dataframe in sqlite db
"""
import sqlite3
db_path = "C:/Users/priye/PythonProjects/database/RetailFirm.db"
con = sqlite3.connect(db_path)
cur = con.cursor()
df.to_sql('student', con, if_exists='replace', index=False)
con.commit()
con.close()
"""

# To impute NaN values using KNN (fancyimpute)
"""
import pandas as pd
import numpy as np
# importing the KNN from fancyimpute library
from fancyimpute import KNN

df = pd.DataFrame( [[np.nan, 2, np.nan, 0],
                    [3, 4, np.nan, 1],
                    [np.nan, np.nan, np.nan, 5],
                    [np.nan, 3, np.nan, 4],
                    [5, 7, 8, 2],
                    [2, 5, 7, 9]],
                   columns=list( 'ABCD' ) )

# printing the dataframe
print( df )

# calling the KNN class
knn_imputer = KNN()
# imputing the missing value with knn imputer
df = knn_imputer.fit_transform( df )

# printing dataframe
print( df ) 
"""

# To impute NaN values using Multiple Imputation by Chained Equation (fancyimpute)
"""

import pandas as pd 
import numpy as np 
# importing the MICE from fancyimpute library 
from fancyimpute import IterativeImputer 
  
df = pd.DataFrame([[np.nan, 2, np.nan, 0], 
                   [3, 4, np.nan, 1], 
                   [np.nan, np.nan, np.nan, 5], 
                   [np.nan, 3, np.nan, 4], 
                   [5,      7,  8,     2], 
                   [2,      5,  7,     9]], 
                  columns = list('ABCD')) 
  
# printing the dataframe 
print(df) 
  
# calling the  MICE class 
mice_imputer = IterativeImputer() 
# imputing the missing value with mice imputer 
df = mice_imputer.fit_transform(df) 
  
# printing dataframe 
print(df) 
"""
"""
import pandas as pd

# Load the missing data file to a Dataframe
file_path ='E:/Xzane/Priyesh/Courses - Training materials/Simplilearn/Machine Learning/' 
           'class notes,ppt,ipynb,datasets,etc/Demo Datasets/MissingData/Data_for_Missing_Values.csv'
df = pd.read_csv(file_path)
print(df.head())
print(df.describe())

"""
